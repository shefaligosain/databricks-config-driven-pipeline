# %%
# Install dependency (run once)
# %pip install pyyaml

# %%
dbutils.library.restartPython()

# %%
import yaml
import os

config_path = "/Workspace/Users/shefali01gosain777@gmail.com/databricks-config-driven-pipeline/configs/pipeline_config.yaml"

with open(config_path, "r") as f:
    config = yaml.safe_load(f)

config
